# %% [markdown]
# **Prepared by:**
#
# Prof. Ashwini Kumar Mathur<br>
# Assistant Professor<br>
# SoCSE

# %% [markdown]
# ## What is Gradient Decent?
#
# Gradient descent is an optimization algorithm commonly used in machine learning and other fields to minimize a function.
#
#
# ### **Key points about gradient descent:**
#
# - It's an iterative algorithm, meaning it takes small steps repeatedly.
# - It needs a function to optimize, like a loss function in machine learning.
# - It requires a learning rate, which controls the size of the steps it takes.
# - It's not guaranteed to find the global minimum, but it usually finds a good local minimum

# %%
import numpy as np

# Define sample data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])

# Implement a simple linear model
def model(x, w, b):
    return w * x + b

# Define the mean squared error loss function
def mean_squared_error(y_true, y_pred):
    return np.mean((y_true - y_pred)**2)

# Set initial parameters
w = 1
b = 0

# %% [markdown]
# ### Implementation of Gradient Decent

# %%
# Learning rate
learning_rate = 0.001

# Gradient descent loop
for i in range(100):
    y_pred = model(x, w, b)
    loss = mean_squared_error(y, y_pred)

    # Calculate gradients
    dw = np.mean(2 * x * (y_pred - y))
    db = np.mean(2 * (y_pred - y))

    # Update parameters
    w = w - learning_rate * dw
    b = b - learning_rate * db

    print("Iteration:", i, "Loss:", loss)

# Print final parameters and loss
print("Final w:", w)
print("Final b:", b)
print("Final loss:", loss)
# Out:
# Iteration: 0 Loss: 1.2206386683301576
# Iteration: 1 Loss: 1.2139767436379094
# Iteration: 2 Loss: 1.2076074445735228
# Iteration: 3 Loss: 1.2015170996010496
# Iteration: 4 Loss: 1.1956926765105358
# Iteration: 5 Loss: 1.190121752520638
# Iteration: 6 Loss: 1.1847924857793561
# Iteration: 7 Loss: 1.1796935881975048
# Iteration: 8 Loss: 1.1748142995526
# Iteration: 9 Loss: 1.1701443628037442
# Iteration: 10 Loss: 1.1656740005608917
# Iteration: 11 Loss: 1.1613938926544956
# Iteration: 12 Loss: 1.1572951547540948
# Iteration: 13 Loss: 1.1533693179867697
# Iteration: 14 Loss: 1.1496083095087268
# Iteration: 15 Loss: 1.146004433985429
# Iteration: 16 Loss: 1.142550355937788
# Iteration: 17 Loss: 1.1392390829139185
# Iteration: 18 Loss: 1.136063949447844
# Iteration: 19 Loss: 1.1330186017683639
# Iteration: 20 Loss: 1.1300969832229844
# Iteration: 21 Loss: 1.127293320383491
# Iteration: 22 Loss: 1.1246021098012746
# Iteration: 23 Loss: 1.1220181053820355
# Iteration: 24 Loss: 1.1195363063508874
# Iteration: 25 Loss: 1.117151945780267
# Iteration: 26 Loss: 1.114860479654326
# Iteration: 27 Loss: 1.112657576444703
# Iteration: 28 Loss: 1.1105391071737898
# Iteration: 29 Loss: 1.1085011359426609
# Iteration: 30 Loss: 1.10653991090197
# Iteration: 31 Loss: 1.1046518556450717
# Iteration: 32 Loss: 1.102833561003639
# Iteration: 33 Loss: 1.1010817772269499
# Iteration: 34 Loss: 1.0993934065269004
# Iteration: 35 Loss: 1.0977654959716439
# Iteration: 36 Loss: 1.096195230711547
# Iteration: 37 Loss: 1.094679927521931
# Iteration: 38 Loss: 1.0932170286477807
# Iteration: 39 Loss: 1.0918040959362905
# Iteration: 40 Loss: 1.0904388052438112
# Iteration: 41 Loss: 1.0891189411043296
# Iteration: 42 Loss: 1.0878423916472906
# Iteration: 43 Loss: 1.0866071437530678
# Iteration: 44 Loss: 1.0854112784349907
# Iteration: 45 Loss: 1.0842529664373237
# Iteration: 46 Loss: 1.0831304640391002
# Iteration: 47 Loss: 1.0820421090541898
# Iteration: 48 Loss: 1.0809863170184122
# Iteration: 49 Loss: 1.0799615775549611
# Iteration: 50 Loss: 1.0789664509097945
# Iteration: 51 Loss: 1.0779995646490403
# Iteration: 52 Loss: 1.0770596105108512
# Iteration: 53 Loss: 1.0761453414044695
# Iteration: 54 Loss: 1.0752555685496374
# Iteration: 55 Loss: 1.0743891587497711
# Iteration: 56 Loss: 1.073545031792659
# Iteration: 57 Loss: 1.072722157972707
# Iteration: 58 Loss: 1.0719195557290626
# Iteration: 59 Loss: 1.0711362893941765
# Iteration: 60 Loss: 1.0703714670476598
# Iteration: 61 Loss: 1.0696242384705044
# Iteration: 62 Loss: 1.0688937931949622
# Iteration: 63 Loss: 1.0681793586456334
# Iteration: 64 Loss: 1.067480198367469
# Iteration: 65 Loss: 1.066795610336655
# Iteration: 66 Loss: 1.066124925350472
# Iteration: 67 Loss: 1.065467505492462
# Iteration: 68 Loss: 1.0648227426693653
# Iteration: 69 Loss: 1.064190057216472
# Iteration: 70 Loss: 1.0635688965682024
# Iteration: 71 Loss: 1.0629587339908504
# Iteration: 72 Loss: 1.0623590673745853
# Iteration: 73 Loss: 1.0617694180819532
# Iteration: 74 Loss: 1.061189329850218
# Iteration: 75 Loss: 1.060618367745041
# Iteration: 76 Loss: 1.0600561171630851
# Iteration: 77 Loss: 1.0595021828812625
# Iteration: 78 Loss: 1.058956188150446
# Iteration: 79 Loss: 1.0584177738315577
# Iteration: 80 Loss: 1.05788659757206
# Iteration: 81 Loss: 1.0573623330209556
# Iteration: 82 Loss: 1.0568446690805031
# Iteration: 83 Loss: 1.0563333091929124
# Iteration: 84 Loss: 1.0558279706604146
# Iteration: 85 Loss: 1.0553283839971095
# Iteration: 86 Loss: 1.0548342923111373
# Iteration: 87 Loss: 1.0543454507157386
# Iteration: 88 Loss: 1.0538616257678504
# Iteration: 89 Loss: 1.0533825949329623
# Iteration: 90 Loss: 1.0529081460749945
# Iteration: 91 Loss: 1.05243807697003
# Iteration: 92 Loss: 1.051972194842792
# Iteration: 93 Loss: 1.0515103159247934
# Iteration: 94 Loss: 1.0510522650331469
# Iteration: 95 Loss: 1.0505978751690743
# Iteration: 96 Loss: 1.050146987135195
# Iteration: 97 Loss: 1.049699449170703
# Iteration: 98 Loss: 1.0492551166036121
# Iteration: 99 Loss: 1.0488138515192578
# Final w: 1.0796359657675738
# Final b: 0.43204164588446603
# Final loss: 1.0488138515192578
# Text(0.5, 1.0, 'Gradient Descent Visualization')

# %%
import numpy as np
import matplotlib.pyplot as plt

import numpy as np

# Define sample data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])

# Set initial parameters
w = 0
b = 0


# Learning rate
learning_rate = 0.001

# Function to calculate predictions
def model(x, w, b):
    return w * x + b

# Function to calculate mean squared error
def mean_squared_error(y_true, y_pred):
    return np.mean((y_true - y_pred)**2)

# Plot initial data and line
plt.scatter(x, y, label='Data points')
plt.plot(x, model(x, w, b), color='red', label='Initial line')

# Gradient descent loop
for i in range(100):
    y_pred = model(x, w, b)
    loss = mean_squared_error(y, y_pred)

    # Calculate gradients
    dw = np.mean(2 * x * (y_pred - y))
    db = np.mean(2 * (y_pred - y))

    # Update parameters
    w = w - learning_rate * dw
    b = b - learning_rate * db

    # Plot updated line
    if i % 10 == 0:  # Plot every 10 iterations for better visualization
        plt.plot(x, model(x, w, b), color='green', alpha=0.3)

# Print final parameters and loss
print("Final w:", w)
print("Final b:", b)
print("Final loss:", loss)

# Plot final line
plt.plot(x, model(x, w, b), color='blue', label='Final line')

# Add labels and legend
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.title('Gradient Descent Visualization')

# Show the plot
plt.show()
# Out:
# Final w: 1.00335504486389
# Final b: 0.34553740739359207
# Final loss: 1.2276075608763026

# %% [markdown]
# ## Class activity excercise : [Intermediate Level ]
#
# Give the short inference via experiment by using differnt loss functions. Inject outliers into dataset and observe what is happening to the loss value. Write your understanding in two to three lines.
